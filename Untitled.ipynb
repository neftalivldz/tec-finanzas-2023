# %%
Nick Zincone
https://developers.refinitiv.com/en/article-catalog/article/using-ai-modeling-to-interpret-10-Q-filings
https://pypi.org/project/sec-api/

# %%
#!pip3 install transformers
#!pip3 install torch
#!conda install -c pytorch torchtext
#!conda install pytorch torchvision -c pytorch
#!pip3 install refinitiv.dataplatform
#!pip3 install refinitiv.data

# %%
# NLP package used to aid in text manipulation
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# Machine Learning modules used to prepare and measure text
from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import BertTokenizer, BertForSequenceClassification, pipeline
import torch

# HTML text processing
from bs4 import BeautifulSoup

# Helper modules
import matplotlib.pyplot as plt
from tqdm.notebook import trange # Progress bar
import pandas as pd

# Refinitiv packages to extract filings data and retrieve price data
import refinitiv.data as rd
from refinitiv.data.content import filings

# Convenient modules to simplify API access to Filings
# %run ./FilingsQuery.ipynb
# %run ./SymbolLookup.ipynb
pd.set_option('display.max_colwidth', 60)

# %%
# Open a session to retrieve Filings data from RDP
rd.open_session()
# Out:
# <refinitiv.data.session.Definition object at 0x17cd6a5e0 {name='workspace'}>

# %%
# Load the models
finbert = BertForSequenceClassification.from_pretrained('yiyanghkust/finbert-fls',num_labels=3)

# %%
# Download the Pre-trained transformer used to process our raw text
tokenizer = BertTokenizer.from_pretrained('yiyanghkust/finbert-fls')

# %%
prediction = nlp("The future for next years sales will increase by 10 %.", top_k=3)
prediction
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 prediction = pytorch.nlp("The future for next years sales will increase by 10 %.", top_k=3)
#       2 prediction
#
# NameError: name 'pytorch' is not defined

# %%
# Sentiment - Download the Pre-trained transformer used to process our raw text
sent_tokenizer = AutoTokenizer.from_pretrained("ProsusAI/finbert")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
# Sentiment - Download the FinBert model used to process our transformed data
model = AutoModelForSequenceClassification.from_pretrained("ProsusAI/finbert")
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
# Use the RIC to define our company identifier
identifier = "MSFT.O" # Tesla

# Data ranges to capture our data sets used to predict sentiment
start = "2010-01-01T00:00:00Z"
end = "2022-10-31T23:59:59Z"

# %%
# Query the Filings service using the Refinitiv Data Library for Python.
#
# Retrieve SEC filings for the specific company - specify the text we want to retrieve
# is defined within the "Management Discussion" section.
response = filings.search.Definition(
   query = FilingsQuery().form_type("10-Q")
                         .orgid(SymbolLookup(ric=identifier).convert())
                         .feed(FilingsQuery.Feed.EDGAR)
                         .sections(["ManagementDiscussion"])
                         .start_date(start)
                         .end_date(end)
                         .limit(100)
                         .graphQL
).get_data()

# %%
response.data.df
# Out:
#      DocumentTitle  Filename  MimeType   Dcn  DocId  FinancialFilingId
# 0             <NA>      <NA>      <NA>  <NA>   <NA>               <NA>
# 1             <NA>      <NA>      <NA>  <NA>   <NA>               <NA>
# 2             <NA>      <NA>      <NA>  <NA>   <NA>               <NA>
# 3             <NA>      <NA>      <NA>  <NA>   <NA>               <NA>
# 4             <NA>      <NA>      <NA>  <NA>   <NA>               <NA>
# ..             ...       ...       ...   ...    ...                ...
# 181           <NA>      <NA>      <NA>  <NA>   <NA>               <NA>
# 182           <NA>      <NA>      <NA>  <NA>   <NA>               <NA>
# 183           <NA>      <NA>      <NA>  <NA>   <NA>               <NA>
# 184           <NA>      <NA>      <NA>  <NA>   <NA>               <NA>
# 185           <NA>      <NA>      <NA>  <NA>   <NA>               <NA>
#
# [186 rows x 6 columns]

# %%
# Retrieve and report the # of reports based on our query
reports = response.data.raw['data']['FinancialFiling']
organization = reports[0]["FilingOrganization"]['Names']['Name']['OrganizationName'][0]['Name']

# %%
# Declare our final results table
results = pd.DataFrame()
dates = []
text = []

# Pull out the filings text for each report
for filing in reversed(reports):
    section = filing['FilingDocument']['Sections']['ManagementDiscussion']['Text']
    filingDate = filing['FilingDocument']['DocumentSummary']['FilingDate']

    if section is not None:
        dates.append(filingDate[:10])
        
        # Process the text. Using BeautifulSoup and other means to clean the data
        beautifulSoupText = BeautifulSoup(section, "html.parser")

        # Clean the data and capture it for later processing
        text.append(beautifulSoupText.prettify(formatter=lambda s: s.replace(u'\xa0', ' ').replace('\r', ' ')))
        results['FilingDate'] = dates
        results['section'] = text

# %%
reports
# Out:
# [{'_metadata': {'totalCount': 38,
#    'cursor': 'WzE2NjY1Njk2MDAwMDAsIjk3Njc1NzcyMjM1Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE2NTg3MDcyMDAwMDAsIjk3NjczNTAxMzc2Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE2NTA4NDQ4MDAwMDAsIjk3NjcyMDY4MzQyIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE2MzUxMjAwMDAwMDAsIjk3NjY1MjY0MTc5Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE2MjczNDQwMDAwMDAsIjk3NjY0MTUyNjYxIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE2MTk1NjgwMDAwMDAsIjk3NjYyNzQ2MTIzIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE2MDM2NzA0MDAwMDAsIjk3NjYwMzg4NjcwIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE1OTU4OTQ0MDAwMDAsIjk3NjU5NTY1MTkwIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE1ODgyMDQ4MDAwMDAsIjk3NjU4NzcxMjg2Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE1NzIzMDcyMDAwMDAsIjk3NjU2OTE3NTgzIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE1NjQzNTg0MDAwMDAsIjk3NjU2MTUyMTgyIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE1NTY0OTYwMDAwMDAsIjk3NjU1MTI5MTk1Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE1NDExMTY4MDAwMDAsIjk3NjUzNDgzMDk0Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE1MzM1MTM2MDAwMDAsIjk3NjUyNjM1NjA5Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE1MjU2NTEyMDAwMDAsIjk3NjUxNzkzMTExIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE1MDk2NjcyMDAwMDAsIjk3NjQ5OTgxODYwIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE1MDE4MDQ4MDAwMDAsIjk3NjQ5MjQxNTMyIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE0OTQzNzQ0MDAwMDAsIjk3NjQ4NDg4NzQ4Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE0NzgwNDQ4MDAwMDAsIjk3NjQ2NzM1NTMwIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE0NzAzNTUyMDAwMDAsIjk3NjQ2MDMwNzg4Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE0NjI4Mzg0MDAwMDAsIjk3NjQ1MjkyMjQxIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE0NDY2ODE2MDAwMDAsIjk3NjQzNjg3MDE5Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE0Mzg5MDU2MDAwMDAsIjk3NjQzMDg0NjY2Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE0MzEzMDI0MDAwMDAsIjk3NjQyMzY4OTU4Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE0MTUzMTg0MDAwMDAsIjk3NjQwODg0NTY3Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzE0MDc0NTYwMDAwMDAsIjk3NjQwMjc3OTE2Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzEzOTk1OTM2MDAwMDAsIjk3NjM5NjcyNjU3Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzEzODM4Njg4MDAwMDAsIjk3NjM4MzI4ODE2Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzEzNzYwMDY0MDAwMDAsIjk3NjM3NjMzNTg2Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzEzNjgxNDQwMDAwMDAsIjk3NjM2OTM3MjMyIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzEzNTIyNDY0MDAwMDAsIjk3NjM1NDMyMzQxIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzEzNDM4NjU2MDAwMDAsIjM0Mzg5NjE3NjgzIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzEzMzY2MDgwMDAwMDAsIjM0Mzg5MDc5OTkyIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzEzMjEyMjg4MDAwMDAsIjM0Mzg3OTY4NDE1Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzEzMTMxMDcyMDAwMDAsIjM0Mzg3NDAyNzYxIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzEzMDUyNDQ4MDAwMDAsIjM0Mzg2ODQ4Njg4Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzEyODk1MjAwMDAwMDAsIjM0Mzg1NTc1MDI5Il0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}},
#  {'_metadata': {'totalCount': 38,
#    'cursor': 'WzEyODE2NTc2MDAwMDAsIjM0Mzc0MTYyOTYwIl0='},
#   'FilingOrganization': {'Names': {'Name': {'OrganizationName': [{'Name': 'TESLA, INC.'}]}}},
#   'FilingDocument': {'Identifiers': [{'OrganizationId': None, 'Dcn': None}],
#    'DocId': None,
#    'FinancialFilingId': None,
#    'Sections': {'ManagementDiscussion': {'Text': None}},
#    'DocumentSummary': {'DocumentTitle': None,
#     'FeedName': None,
#     'FormType': None,
#     'HighLevelCategory': None,
#     'MidLevelCategory': None,
#     'FilingDate': None,
#     'SecAccessionNumber': None,
#     'SizeInBytes': None},
#    'FilesMetaData': [{'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None},
#     {'FileName': None, 'MimeType': None}]}}]
