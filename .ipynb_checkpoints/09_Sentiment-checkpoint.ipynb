# %%
# !pip3 install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.17.1-py2.py3-none-any.whl (636 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 636.8/636.8 kB 1.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting nltk>=3.1
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 3.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: tqdm in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from nltk>=3.1->textblob) (4.65.0)
# Requirement already satisfied: joblib in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from nltk>=3.1->textblob) (1.2.0)
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.6/96.6 kB 4.1 MB/s eta 0:00:00
# Collecting regex>=2021.8.3
#   Downloading regex-2023.3.23-cp38-cp38-macosx_11_0_arm64.whl (288 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.7/288.7 kB 4.5 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: regex, click, nltk, textblob
# Successfully installed click-8.1.3 nltk-3.8.1 regex-2023.3.23 textblob-0.17.1

# %%
import eikon as ek
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
from textblob import TextBlob
import datetime
from datetime import time
import warnings
warnings.filterwarnings("ignore")
import configparser as cp

# %%
cfg = cp.ConfigParser()
cfg.read('../refinitiv.cfg')
ek.set_app_key(cfg['eikon']['app_id'])

# %%
from datetime import datetime, timedelta
end = datetime.today()
start = end - timedelta(days=(365.2*4))
print(start, end)
# Out:
# 2019-04-11 19:50:22.501419 2023-04-11 15:02:22.501419

# %%
df = ek.get_news_headlines('R:IBM.N AND Language:LEN', date_to = end, count=100)
df.head()
# Out:
#                                           versionCreated  \
# 2023-04-11 13:10:28.894 2023-04-11 13:10:28.894000+00:00
# 2023-04-11 13:04:01.000        2023-04-11 13:04:01+00:00
# 2023-04-11 12:30:00.652 2023-04-11 12:30:00.652000+00:00
# 2023-04-11 06:00:41.391 2023-04-11 06:00:41.391000+00:00
# 2023-04-10 23:18:47.977 2023-04-10 23:18:47.977000+00:00
#
#                                                                       text  \
# 2023-04-11 13:10:28.894  eCIFM® awarded a multi-year Asset Management S...
# 2023-04-11 13:04:01.000          IBM - IBM Releases IBM Impact Report 2022
# 2023-04-11 12:30:00.652  Rocket Software to Explore the Impact of Artif...
# 2023-04-11 06:00:41.391          REG-Intnl Bus. Mach: Doc re: Form DEFA14A
# 2023-04-10 23:18:47.977  IBM (IBM) Outpaces Stock Market Gains: What Yo...
#
#                                                                    storyId  \
# 2023-04-11 13:10:28.894  urn:newsml:newswire.refinitiv.com:20230411:nPn...
# 2023-04-11 13:04:01.000  urn:newsml:newswire.refinitiv.com:20230411:nND...
# 2023-04-11 12:30:00.652  urn:newsml:newswire.refinitiv.com:20230411:nBw...
# 2023-04-11 06:00:41.391  urn:newsml:newswire.refinitiv.com:20230411:nPR...
# 2023-04-10 23:18:47.977  urn:newsml:newswire.refinitiv.com:20230410:nNR...
#
#                         sourceCode
# 2023-04-11 13:10:28.894     NS:PRN
# 2023-04-11 13:04:01.000    NS:PUBT
# 2023-04-11 12:30:00.652     NS:BSW
# 2023-04-11 06:00:41.391     NS:PRN
# 2023-04-10 23:18:47.977  NS:ZACKSC

# %%
df['Polarity'] = np.nan
df['Subjectivity'] = np.nan
df['Score'] = np.nan

# %%
for idx, storyId in enumerate(df['storyId'].values):  #for each row in our df dataframe
    newsText = ek.get_news_story(storyId) #get the news story
    if newsText:
        soup = BeautifulSoup(newsText,"lxml") #create a BeautifulSoup object from our HTML news article
        sentA = TextBlob(soup.get_text()) #pass the text only article to TextBlob to anaylse
        df['Polarity'].iloc[idx] = sentA.sentiment.polarity #write sentiment polarity back to df
        df['Subjectivity'].iloc[idx] = sentA.sentiment.subjectivity #write sentiment subjectivity score back to df
        if sentA.sentiment.polarity >= 0.05: # attribute bucket to sentiment polartiy
            score = 'positive'
        elif  -.05 < sentA.sentiment.polarity < 0.05:
            score = 'neutral'
        else:
            score = 'negative'
        df['Score'].iloc[idx] = score #write score back to df
df.head()
# Out:
#                                           versionCreated  \
# 2023-04-11 13:10:28.894 2023-04-11 13:10:28.894000+00:00
# 2023-04-11 13:04:01.000        2023-04-11 13:04:01+00:00
# 2023-04-11 12:30:00.652 2023-04-11 12:30:00.652000+00:00
# 2023-04-11 06:00:41.391 2023-04-11 06:00:41.391000+00:00
# 2023-04-10 23:18:47.977 2023-04-10 23:18:47.977000+00:00
#
#                                                                       text  \
# 2023-04-11 13:10:28.894  eCIFM® awarded a multi-year Asset Management S...
# 2023-04-11 13:04:01.000          IBM - IBM Releases IBM Impact Report 2022
# 2023-04-11 12:30:00.652  Rocket Software to Explore the Impact of Artif...
# 2023-04-11 06:00:41.391          REG-Intnl Bus. Mach: Doc re: Form DEFA14A
# 2023-04-10 23:18:47.977  IBM (IBM) Outpaces Stock Market Gains: What Yo...
#
#                                                                    storyId  \
# 2023-04-11 13:10:28.894  urn:newsml:newswire.refinitiv.com:20230411:nPn...
# 2023-04-11 13:04:01.000  urn:newsml:newswire.refinitiv.com:20230411:nND...
# 2023-04-11 12:30:00.652  urn:newsml:newswire.refinitiv.com:20230411:nBw...
# 2023-04-11 06:00:41.391  urn:newsml:newswire.refinitiv.com:20230411:nPR...
# 2023-04-10 23:18:47.977  urn:newsml:newswire.refinitiv.com:20230410:nNR...
#
#                         sourceCode  Polarity  Subjectivity     Score
# 2023-04-11 13:10:28.894     NS:PRN  0.097842      0.463641  positive
# 2023-04-11 13:04:01.000    NS:PUBT  0.149533      0.354352  positive
# 2023-04-11 12:30:00.652     NS:BSW  0.090130      0.335807  positive
# 2023-04-11 06:00:41.391     NS:PRN  0.200000      0.200000  positive
# 2023-04-10 23:18:47.977  NS:ZACKSC  0.065648      0.546327  positive

# %%
start = df['versionCreated'].min().replace(hour=0,minute=0,second=0,microsecond=0).strftime('%Y/%m/%d')
end = df['versionCreated'].max().replace(hour=0,minute=0,second=0,microsecond=0).strftime('%Y/%m/%d')
Minute = ek.get_timeseries(["IBM.N"], start_date=start, interval="minute")
Minute.tail()
# Out:
# IBM.N                  HIGH     LOW    OPEN   CLOSE  COUNT  VOLUME
# Date
# 2023-04-11 19:45:00  130.78  130.74  130.77  130.74     16    1024
# 2023-04-11 19:46:00  130.75  130.69  130.73   130.7     34    2921
# 2023-04-11 19:47:00  130.69  130.65  130.69  130.65     24    2392
# 2023-04-11 19:48:00  130.65  130.63  130.64  130.64     21    2699
# 2023-04-11 19:49:00  130.64  130.59  130.64  130.62     28    2316

# %%
df['twoM'] = np.nan
df['fiveM'] = np.nan
df['tenM'] = np.nan
df['thirtyM'] = np.nan
df.head(2)
# Out:
#                                           versionCreated  \
# 2023-04-11 13:10:28.894 2023-04-11 13:10:28.894000+00:00
# 2023-04-11 13:04:01.000        2023-04-11 13:04:01+00:00
#
#                                                                       text  \
# 2023-04-11 13:10:28.894  eCIFM® awarded a multi-year Asset Management S...
# 2023-04-11 13:04:01.000          IBM - IBM Releases IBM Impact Report 2022
#
#                                                                    storyId  \
# 2023-04-11 13:10:28.894  urn:newsml:newswire.refinitiv.com:20230411:nPn...
# 2023-04-11 13:04:01.000  urn:newsml:newswire.refinitiv.com:20230411:nND...
#
#                         sourceCode  Polarity  Subjectivity     Score  twoM  \
# 2023-04-11 13:10:28.894     NS:PRN  0.097842      0.463641  positive   NaN
# 2023-04-11 13:04:01.000    NS:PUBT  0.149533      0.354352  positive   NaN
#
#                          fiveM  tenM  thirtyM
# 2023-04-11 13:10:28.894    NaN   NaN      NaN
# 2023-04-11 13:04:01.000    NaN   NaN      NaN

# %%
for idx, newsDate in enumerate(df['versionCreated'].values):
    sTime = df['versionCreated'][idx]
    sTime = sTime.replace(second=0,microsecond=0)
    try:
        t0 = Minute.iloc[Minute.index.get_loc(sTime),2]
        df['twoM'][idx] = ((Minute.iloc[Minute.index.get_loc((sTime + datetime.timedelta(minutes=2))),3]/(t0)-1)*100)
        df['fiveM'][idx] = ((Minute.iloc[Minute.index.get_loc((sTime + datetime.timedelta(minutes=5))),3]/(t0)-1)*100)
        df['tenM'][idx] = ((Minute.iloc[Minute.index.get_loc((sTime + datetime.timedelta(minutes=10))),3]/(t0)-1)*100) 
        df['thirtyM'][idx] = ((Minute.iloc[Minute.index.get_loc((sTime + datetime.timedelta(minutes=30))),3]/(t0)-1)*100)
    except:
        pass
df.head()
# Out:
#                                           versionCreated  \
# 2023-04-11 13:10:28.894 2023-04-11 13:10:28.894000+00:00
# 2023-04-11 13:04:01.000        2023-04-11 13:04:01+00:00
# 2023-04-11 12:30:00.652 2023-04-11 12:30:00.652000+00:00
# 2023-04-11 06:00:41.391 2023-04-11 06:00:41.391000+00:00
# 2023-04-10 23:18:47.977 2023-04-10 23:18:47.977000+00:00
#
#                                                                       text  \
# 2023-04-11 13:10:28.894  eCIFM® awarded a multi-year Asset Management S...
# 2023-04-11 13:04:01.000          IBM - IBM Releases IBM Impact Report 2022
# 2023-04-11 12:30:00.652  Rocket Software to Explore the Impact of Artif...
# 2023-04-11 06:00:41.391          REG-Intnl Bus. Mach: Doc re: Form DEFA14A
# 2023-04-10 23:18:47.977  IBM (IBM) Outpaces Stock Market Gains: What Yo...
#
#                                                                    storyId  \
# 2023-04-11 13:10:28.894  urn:newsml:newswire.refinitiv.com:20230411:nPn...
# 2023-04-11 13:04:01.000  urn:newsml:newswire.refinitiv.com:20230411:nND...
# 2023-04-11 12:30:00.652  urn:newsml:newswire.refinitiv.com:20230411:nBw...
# 2023-04-11 06:00:41.391  urn:newsml:newswire.refinitiv.com:20230411:nPR...
# 2023-04-10 23:18:47.977  urn:newsml:newswire.refinitiv.com:20230410:nNR...
#
#                         sourceCode  Polarity  Subjectivity     Score  twoM  \
# 2023-04-11 13:10:28.894     NS:PRN  0.097842      0.463641  positive   NaN
# 2023-04-11 13:04:01.000    NS:PUBT  0.149533      0.354352  positive   NaN
# 2023-04-11 12:30:00.652     NS:BSW  0.090130      0.335807  positive   NaN
# 2023-04-11 06:00:41.391     NS:PRN  0.200000      0.200000  positive   NaN
# 2023-04-10 23:18:47.977  NS:ZACKSC  0.065648      0.546327  positive   NaN
#
#                          fiveM  tenM  thirtyM
# 2023-04-11 13:10:28.894    NaN   NaN      NaN
# 2023-04-11 13:04:01.000    NaN   NaN      NaN
# 2023-04-11 12:30:00.652    NaN   NaN      NaN
# 2023-04-11 06:00:41.391    NaN   NaN      NaN
# 2023-04-10 23:18:47.977    NaN   NaN      NaN

# %%
grouped = df.groupby(['Score']).mean()
grouped
# Out:
#           Polarity  Subjectivity  twoM  fiveM  tenM  thirtyM
# Score
# negative -0.077822      0.339391   NaN    NaN   NaN      NaN
# neutral   0.001976      0.082720   NaN    NaN   NaN      NaN
# positive  0.148069      0.418141   NaN    NaN   NaN      NaN
