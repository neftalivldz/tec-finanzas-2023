# %% [markdown]
# # Información y Programación Financiera, TI, Algoritmos y Ciencia de Datos

# %% [markdown]
# Neftalí Valdez
#
# <a href="http://twitter.com/neftalivldz" target="_blank">@neftalivldz</a> | <a href="mailto:nvaldez@tec.mx">nvaldez@tec.mx</a>

# %% [markdown]
# # Importar librerías

# %%
# !pip3 install statsmodels
# Out:
# Collecting statsmodels
#   Downloading statsmodels-0.13.5-cp38-cp38-macosx_11_0_arm64.whl (9.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 9.6 MB/s eta 0:00:000m eta 0:00:01:01:01
# Requirement already satisfied: packaging>=21.3 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from statsmodels) (23.0)
# Requirement already satisfied: numpy>=1.17 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from statsmodels) (1.24.1)
# Requirement already satisfied: scipy>=1.3 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: pandas>=0.25 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from statsmodels) (1.5.3)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.8/233.8 kB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from pandas>=0.25->statsmodels) (2022.7.1)
# Requirement already satisfied: six in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.3 statsmodels-0.13.5

# %%
import eikon as ek  # the Eikon Python wrapper package
import numpy as np  # NumPy
import pandas as pd  # pandas
import cufflinks as cf  # Cufflinks
import configparser as cp
cf.set_config_file(offline=True)  # set the plotting mode to offline

from pathlib import Path
import pandas_datareader.data as web

import statsmodels.api as sm
from statsmodels.regression.rolling import RollingOLS
from sklearn.preprocessing import scale
import talib

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 14
#      12 from statsmodels.regression.rolling import RollingOLS
#      13 from sklearn.preprocessing import scale
# ---> 14 import talib
#      16 import matplotlib.pyplot as plt
#      17 import seaborn as sns
#
# ModuleNotFoundError: No module named 'talib'

# %%
cfg = cp.ConfigParser()
cfg.read('../refinitiv.cfg')
ek.set_app_key(cfg['eikon']['app_id'])

# %%
from datetime import datetime, timedelta
today = datetime.today()
past = today - timedelta(days=(365*5))
print(today, past)
df = ek.get_timeseries('AAPL.O', start_date = past, end_date = today, fields=['HIGH', 'LOW', 'CLOSE'], interval="daily")
df = df.rename(columns={"HIGH": "high", "LOW": "low", "CLOSE": "close"})
df
# Out:
# 2023-03-30 18:48:45.899639 2018-03-31 18:48:45.899639
# AAPL.O           high      low    close
# Date
# 2018-04-02     42.235  41.1175    41.67
# 2018-04-03  42.186375    41.22  42.0975
# 2018-04-04    43.0025  41.1925  42.9025
# 2018-04-05    43.5576    43.02     43.2
# 2018-04-06      43.12    42.05   42.095
# ...               ...      ...      ...
# 2023-03-24     160.34   157.85   160.25
# 2023-03-27     160.77   157.87   158.28
# 2023-03-28     158.49   155.98   157.65
# 2023-03-29     161.05   159.35   160.77
# 2023-03-30     162.47  161.271   162.36
#
# [1259 rows x 3 columns]

# %% [markdown]
# ## TA-Lib: Function Groups

# %% [markdown]
# List number of available functions by group

# %%
function_groups = ['Overlap Studies',
                   'Momentum Indicators',
                   'Volume Indicators',
                   'Volatility Indicators',
                   'Price Transform',
                   'Cycle Indicators',
                   'Pattern Recognition',
                   'Statistic Functions',
                   'Math Transform',
                   'Math Operators']

# %%
df['PLUS_DM'] = talib.PLUS_DM(df.high, df.low, timeperiod=10)
df['MINUS_DM'] = talib.MINUS_DM(df.high, df.low, timeperiod=10)

# %%
df
# Out:
# AAPL.O          high      low    close    PLUS_DM   MINUS_DM
# Date
# 2017-03-27    35.305   34.655    35.22        NaN        NaN
# 2017-03-28     36.01   35.155    35.95        NaN        NaN
# 2017-03-29   36.1225  35.7975    36.03        NaN        NaN
# 2017-03-30    36.125   35.875  35.9825        NaN        NaN
# 2017-03-31   36.0675  35.7525   35.915        NaN        NaN
# ...              ...      ...      ...        ...        ...
# 2022-03-17     161.0   157.63   160.62   9.320579  14.957475
# 2022-03-18    164.48   159.76   163.98  11.868521  13.461727
# 2022-03-21    166.35  163.015   165.38  12.551669  12.115554
# 2022-03-22    169.42   164.91   168.82  14.366502  10.903999
# 2022-03-23  170.4852   167.65  170.445  13.995052   9.813599
#
# [1258 rows x 5 columns]

# %%
ax = df[['close', 'PLUS_DM', 'MINUS_DM']].plot(figsize=(14, 4),
                                               secondary_y=[
                                                   'PLUS_DM', 'MINUS_DM'],
                                               style=['-', '--', '_'],
                                              rot=0)
ax.set_xlabel('')
sns.despine()
plt.tight_layout()

# %%
df
# Out:
# AMXL.MX      high    low  close   PLUS_DM  MINUS_DM
# Date
# 2017-03-24  13.39  13.21  13.32       NaN       NaN
# 2017-03-27  13.59  13.19  13.56       NaN       NaN
# 2017-03-28  13.71  13.46  13.68       NaN       NaN
# 2017-03-29   13.9  13.56  13.76       NaN       NaN
# 2017-03-30  13.75  13.41  13.53       NaN       NaN
# ...           ...    ...    ...       ...       ...
# 2022-03-15  19.93  19.51  19.81  1.032366  0.766625
# 2022-03-16  20.25  19.76   20.1  1.249129  0.689963
# 2022-03-17  20.55  20.01  20.38  1.424216  0.620966
# 2022-03-18  20.53  19.78  20.33  1.281794  0.788870
# 2022-03-22  20.94  20.27  20.83  1.563615  0.709983
#
# [1256 rows x 5 columns]

# %%
df['position'] = np.where(df['PLUS_DM'] > df['MINUS_DM'], 1, -1)
df.dropna(inplace=True)
df['position'].plot(ylim=[-1.1, 1.1],
                               title='Market Positioning',
                               figsize=(10, 6));

# %%
df['returns'] = np.log(df['close'] / df['close'].shift(1))
df['returns'].hist(bins=35, figsize=(10, 6));

# %%
df['strategy'] = df['position'].shift(1) * df['returns']
df['strategy'].hist(bins=35, figsize=(10, 6));

# %%
df[['returns', 'strategy']].sum()
df[['returns', 'strategy']].sum().apply(np.exp)
# Out:
# AAPL.O
# returns     4.756383
# strategy    3.127561
# dtype: float64

# %%
np.cumsum(df['returns'])
# Out:
# Date
# 2017-04-07         NaN
# 2017-04-10   -0.001187
# 2017-04-11   -0.012001
# 2017-04-12   -0.010802
# 2017-04-13   -0.016105
#                 ...
# 2022-03-17    1.500116
# 2022-03-18    1.520819
# 2022-03-21    1.529321
# 2022-03-22    1.549908
# 2022-03-23    1.559488
# Name: returns, Length: 1249, dtype: object

# %%
df['returns_cs'] = np.cumsum(df['returns'])
df['strategy_cs'] = np.cumsum(df['strategy'])

# %%
df[['returns_cs', 'strategy_cs']].plot(figsize=(10, 6));
