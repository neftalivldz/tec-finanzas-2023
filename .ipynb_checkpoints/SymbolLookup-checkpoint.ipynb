# %%
#https://github.com/Refinitiv-API-Samples/Article.RD.Python.PredictiveModellingForFilings/blob/main/SymbolLookup.ipynb

# %%
#!pip3 install refinitiv.dataplatform
# Out:
# Collecting refinitiv.dataplatform
#   Downloading refinitiv_dataplatform-1.0.0a21-py3-none-any.whl (498 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 498.1/498.1 kB 2.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: appdirs>=1.4.3 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (1.4.4)
# Requirement already satisfied: websocket-client!=1.0.0,>=0.54.0 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (1.4.2)
# Requirement already satisfied: httpx>=0.18.0 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (0.23.3)
# Requirement already satisfied: pandas>=1.0.0 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (1.5.3)
# Requirement already satisfied: certifi in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (2022.12.7)
# Requirement already satisfied: h2==3.* in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (3.2.0)
# Requirement already satisfied: nest-asyncio in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (1.5.6)
# Requirement already satisfied: rfc3986==1.* in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (1.5.0)
# Requirement already satisfied: datetime in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (5.0)
# Requirement already satisfied: deprecation in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (2.1.0)
# Collecting idna==2.*
#   Using cached idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting watchdog>=0.10.2
#   Downloading watchdog-3.0.0-cp38-cp38-macosx_11_0_arm64.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: chardet==3.* in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (3.0.4)
# Collecting validators
#   Downloading validators-0.20.0.tar.gz (30 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: requests==2.* in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (2.28.2)
# Requirement already satisfied: numpy>=1.11.0 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (1.24.2)
# Collecting eventemitter>=0.2.0
#   Downloading eventemitter-0.2.0.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Collecting python-configuration!=0.8.0,>=0.7.1
#   Downloading python_configuration-0.8.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: python-dateutil in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (2.8.2)
# Requirement already satisfied: scipy in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from refinitiv.dataplatform) (1.10.1)
# Requirement already satisfied: hpack<4,>=3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from h2==3.*->refinitiv.dataplatform) (3.0.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from h2==3.*->refinitiv.dataplatform) (5.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from requests==2.*->refinitiv.dataplatform) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from requests==2.*->refinitiv.dataplatform) (3.0.1)
# Requirement already satisfied: sniffio in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from httpx>=0.18.0->refinitiv.dataplatform) (1.3.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from httpx>=0.18.0->refinitiv.dataplatform) (0.16.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from pandas>=1.0.0->refinitiv.dataplatform) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from python-dateutil->refinitiv.dataplatform) (1.16.0)
# Requirement already satisfied: zope.interface in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from datetime->refinitiv.dataplatform) (5.5.2)
# Requirement already satisfied: packaging in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from deprecation->refinitiv.dataplatform) (23.0)
# Requirement already satisfied: decorator>=3.4.0 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from validators->refinitiv.dataplatform) (5.1.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from httpcore<0.17.0,>=0.15.0->httpx>=0.18.0->refinitiv.dataplatform) (3.6.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from httpcore<0.17.0,>=0.15.0->httpx>=0.18.0->refinitiv.dataplatform) (0.14.0)
# Requirement already satisfied: setuptools in /opt/homebrew/Caskroom/miniforge/base/envs/mlp/lib/python3.8/site-packages (from zope.interface->datetime->refinitiv.dataplatform) (65.6.3)
# Building wheels for collected packages: eventemitter, validators
#   Building wheel for eventemitter (setup.py) ... done
#   Created wheel for eventemitter: filename=eventemitter-0.2.0-py3-none-any.whl size=12942 sha256=7485be76c39296bf7456701b45a7f4046eb619c9a44ec9a851315128ab713045
#   Stored in directory: /Users/neftalivaldez/Library/Caches/pip/wheels/8b/88/36/7702af81095e6beb49ca3dd392ce9141cf56dc07a8568b686e
#   Building wheel for validators (setup.py) ... done
#   Created wheel for validators: filename=validators-0.20.0-py3-none-any.whl size=19581 sha256=cc9a12a573e717541499b49f732f74af411efe1f6df05eebdbd5d3979a1122cd
#   Stored in directory: /Users/neftalivaldez/Library/Caches/pip/wheels/cb/aa/fe/3316d4394e9ad09ea76561bd5be33f6d01828ff125ab2a3395
# Successfully built eventemitter validators
# Installing collected packages: eventemitter, watchdog, validators, python-configuration, idna, refinitiv.dataplatform
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
# Successfully installed eventemitter-0.2.0 idna-2.10 python-configuration-0.8.2 refinitiv.dataplatform-1.0.0a21 validators-0.20.0 watchdog-3.0.0

# %%
from refinitiv.data.delivery import endpoint_request
import warnings

# %%
class SymbolLookup:
    """The SymbolLookup is a convenient helper interface to convert commonly used symbols such as ticker, isin, cusip, sedol and RIC to 
       the rganization permID used by the Filings service.
       
       To start:
       
       1. Create a Symbol Lookup object, specifying the symbol
          lookup = FilingsQuery(ticker="<TICKER>" | isin="<ISIN>" | cusip="<CUSIP>" | sedol="<CUSIP>" | ric="<RIC>") 
          
       2. Optionally specify the MIC If using the ticker. The MIC code is used to resolve the exchange of the ticker.  For example:
          lookup.mic("XNAS")  # Nasdaq
          
       3. Perform the conversion
          permid = lookup.convert()
    """
    # MIC code - optionally used when specifying the ticker
    def mic(self, mic):
        """Defines the Organization ID used to query across the Filings database
        """
        if mic is None: 
            raise NameError('MIC must exist')  
            
        self.__mic = mic
        return self
    
    # Convert the symbol
    def convert(self):
        identifier_type, value = self.__identifier()
        
        body = {}
        
        # Determine type request body
        if identifier_type == "ExchangeTicker" and not self.__mic is None:
            # Apply our request to include the MIC
            body = self.__body_ticker_params(value, self.__mic)
        else:
            body = self.__body_params(identifier_type, value)
        
        # Request with Body Parameter - Symbology Lookup
        request_definition = endpoint_request.Definition(
            method = rd.delivery.endpoint_request.RequestMethod.POST,
            url = 'https://api.refinitiv.com/discovery/symbology/v1/lookup',
            body_parameters = body
        )
        
        response = request_definition.get_data()
        if not response.is_success:
            raise Exception(f'Failed to convert {identifier_type} symbol: {value}. {response.http_status}')
            
        results = response.data.raw["data"][0]["output"]
        
        if len(results) == 0:
            raise Exception('Request failed to match symbol.  No match returned.')
            
        matches = []
        for match in results:
            matches.append(match['value'])
            
        if len(matches) > 1:
            warnings.formatwarning = self.__warning_on_one_line            
            warnings.warn(f'Found multiple matches: {matches}.  Selecting the first one')
            
        return matches[0]
    
    def __warning_on_one_line(self, message, category, filename, lineno, file=None, line=None):
        return ' %s:%s: %s:%s' % (filename, lineno, category.__name__, message)
    
    def __body_params(self, identifier_type, value):
        return {
            "from": [
                {
                    "identifierTypes": [identifier_type],
                    "values": [value]
                }
            ],
            "to": [
                {
                    "identifierTypes": ["PermID"],
                    "objectTypes": ["organization"]
                }
            ],
            "type": "auto"
        }
    
    def __body_ticker_params(self, ticker, mic):
        return {
            "from": [
                {
                    "values": [
                      {
                          "exchangeTicker": ticker,
                          "MIC": mic
                      }
                    ]
                }
            ],
            "to": [
                {
                    "identifierTypes": ["PermID"],
                    "objectTypes": ["organization"]
                }
            ],
            "reference": [
                "name", 
                "status",
                "classification"
            ],
            "type": "predefined",
            "route": "ExchangeTickerMicToOrganization"
        }
    
    def __identifier(self):
        if not self.__ticker is None:
            return ("ExchangeTicker", self.__ticker)
        if not self.__ric is None:
            return ("RIC", self.__ric)
        if not self.__isin is None:
            return ("Isin", self.__isin)
        if not self.__cusip is None:
            return ("Cusip", self.__cusip)
        if not self.__sedol is None:
            return ("Sedol", self.__sedol)
        raise NameError('At least one type must be specified')  
    
    # Instantiate a SearchBrowser object
    def __init__(self, ticker=None, ric=None, isin=None, cusip=None, sedol=None):
        self.__ticker = ticker
        self.__ric = ric
        self.__isin = isin
        self.__cusip = cusip
        self.__sedol = sedol
        self.__mic = None
